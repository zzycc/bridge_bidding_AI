# %%
# !tar chvfz notebook.tar.gz *
# Out:
# Bidding_seqence_append.ipynb
# E.csv
# N.csv
# S.csv
# Untitled.ipynb
# Untitled1.ipynb
# Unzip.ipynb
# W.csv
# backup/
# backup/combats_train_hot_label_save_file_back12_30000.txt
# backup/bridge_model.h5
# backup/train_data_without_feature_savefile.txt
# backup/train_data_savefile_80000.txt
# backup/bridge_model_80000.h5
# backup/bridge_model_200000_without_feature.h5
# backup/combats_train_hot_label_save_file_80000.txt
# backup/combats_train_hot_label_save_file.txt
# backup/train_data_savefile.txt
# backup/train_data_savefile_back12_30000.txt
# backup/combats_train_hot_label_without_feature.txt
# bridge-Copy2.ipynb
# bridge-back12.ipynb
# bridge-withfeature.ipynb
# bridge.ipynb
# bridge_model.h5
# bridge_model_200000_without_feature.h5
# bridge_model_80000.h5
# bridge_model_80000_LSTM.h5
# bridge_test
# bridge_test.csv
# bridge_test_output.csv
# bridge_test_output1.csv
# bridge_test_output2.csv
# combats_train_hot_label_save_file.txt
# combats_train_hot_label_save_file_80000.txt
# ...
